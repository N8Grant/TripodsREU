# %% [markdown]
# # Vizualization pt.2
# In this notebook I will split the patients up depending on whether or not they have certain gene characteristics. Then use teh same vizualizations as before to see if there are any meaningful differences.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import TumorDecon as td
from scipy.stats import wilcoxon
import seaborn as sns
from itertools import combinations
from scipy.stats import mannwhitneyu

# %% [markdown]
# ## Aggregate Data

# %%
presence_df = pd.read_csv('C:/Users/NathanGrant/Programs/TripodsREU/data/uvm_tcga_pan_can_atlas_2018/data_CNA.txt',delimiter='\t', index_col="Hugo_Symbol")

# %%
presence_df.head()
# Out:
#              Entrez_Gene_Id Cytoband  TCGA-RZ-AB0B-01  TCGA-V3-A9ZX-01  \
# Hugo_Symbol
# ACAP3              116983.0  1p36.33               -1                0
# ACTRT2             140625.0  1p36.32               -1                0
# AGRN               375790.0  1p36.33               -1                0
# ANKRD65            441869.0  1p36.33               -1                0
# ATAD3A              55210.0  1p36.33               -1                0
#
#              TCGA-V3-A9ZY-01  TCGA-V4-A9E5-01  TCGA-V4-A9E7-01  \
# Hugo_Symbol
# ACAP3                      0                0               -2
# ACTRT2                     0                0               -2
# AGRN                       0                0               -2
# ANKRD65                    0                0               -2
# ATAD3A                     0                0               -2
#
#              TCGA-V4-A9E8-01  TCGA-V4-A9E9-01  TCGA-V4-A9EA-01  ...  \
# Hugo_Symbol                                                     ...
# ACAP3                     -1                0                0  ...
# ACTRT2                    -1                0                0  ...
# AGRN                      -1                0                0  ...
# ANKRD65                   -1                0                0  ...
# ATAD3A                    -1                0                0  ...
#
#              TCGA-WC-A885-01  TCGA-WC-A888-01  TCGA-WC-A88A-01  \
# Hugo_Symbol
# ACAP3                      0                0                0
# ACTRT2                     0                0                0
# AGRN                       0                0                0
# ANKRD65                    0                0                0
# ATAD3A                     0                0                0
#
#              TCGA-WC-AA9A-01  TCGA-WC-AA9E-01  TCGA-YZ-A980-01  \
# Hugo_Symbol
# ACAP3                     -1               -1                0
# ACTRT2                    -1               -1                0
# AGRN                      -1               -1                0
# ANKRD65                   -1               -1                0
# ATAD3A                    -1               -1                0
#
#              TCGA-YZ-A982-01  TCGA-YZ-A983-01  TCGA-YZ-A984-01  \
# Hugo_Symbol
# ACAP3                     -1                0                0
# ACTRT2                    -1                0                0
# AGRN                      -1                0                0
# ANKRD65                   -1                0                0
# ATAD3A                    -1                0                0
#
#              TCGA-YZ-A985-01
# Hugo_Symbol
# ACAP3                      0
# ACTRT2                     0
# AGRN                       0
# ANKRD65                    0
# ATAD3A                     0
#
# [5 rows x 82 columns]

# %%
results_df = pd.read_excel("C:/Users/NathanGrant/Programs/TripodsREU/data/CibersortResults/UVMRun1/CIBERSORTOutput_Job2.xlsx",index_col="Input Sample")

# %%
results_df.head()
# Out:
#                  B cells naive  B cells memory  Plasma cells  T cells CD8  \
# Input Sample
# TCGA-RZ-AB0B-01       0.000000        0.000000      0.043900     0.000000
# TCGA-V3-A9ZX-01       0.000800        0.002109      0.003043     0.261506
# TCGA-V3-A9ZY-01       0.102940        0.000000      0.075362     0.108698
# TCGA-V4-A9E5-01       0.012469        0.000000      0.003132     0.000000
# TCGA-V4-A9E7-01       0.046416        0.000000      0.201083     0.084126
#
#                  T cells CD4 naive  T cells CD4 memory resting  \
# Input Sample
# TCGA-RZ-AB0B-01                0.0                    0.182354
# TCGA-V3-A9ZX-01                0.0                    0.000000
# TCGA-V3-A9ZY-01                0.0                    0.043593
# TCGA-V4-A9E5-01                0.0                    0.138271
# TCGA-V4-A9E7-01                0.0                    0.000000
#
#                  T cells CD4 memory activated  T cells follicular helper  \
# Input Sample
# TCGA-RZ-AB0B-01                           0.0                   0.034866
# TCGA-V3-A9ZX-01                           0.0                   0.095574
# TCGA-V3-A9ZY-01                           0.0                   0.012877
# TCGA-V4-A9E5-01                           0.0                   0.008064
# TCGA-V4-A9E7-01                           0.0                   0.038514
#
#                  T cells regulatory (Tregs)  T cells gamma delta  ...  \
# Input Sample                                                      ...
# TCGA-RZ-AB0B-01                    0.099392                  0.0  ...
# TCGA-V3-A9ZX-01                    0.003347                  0.0  ...
# TCGA-V3-A9ZY-01                    0.073627                  0.0  ...
# TCGA-V4-A9E5-01                    0.062064                  0.0  ...
# TCGA-V4-A9E7-01                    0.000000                  0.0  ...
#
#                  Macrophages M2  Dendritic cells resting  \
# Input Sample
# TCGA-RZ-AB0B-01        0.068259                 0.003922
# TCGA-V3-A9ZX-01        0.231561                 0.013261
# TCGA-V3-A9ZY-01        0.478309                 0.000000
# TCGA-V4-A9E5-01        0.264959                 0.004574
# TCGA-V4-A9E7-01        0.469406                 0.000000
#
#                  Dendritic cells activated  Mast cells resting  \
# Input Sample
# TCGA-RZ-AB0B-01                        0.0            0.268964
# TCGA-V3-A9ZX-01                        0.0            0.207099
# TCGA-V3-A9ZY-01                        0.0            0.036752
# TCGA-V4-A9E5-01                        0.0            0.268041
# TCGA-V4-A9E7-01                        0.0            0.072276
#
#                  Mast cells activated  Eosinophils  Neutrophils  P-value  \
# Input Sample
# TCGA-RZ-AB0B-01                     0          0.0            0     0.73
# TCGA-V3-A9ZX-01                     0          0.0            0     0.54
# TCGA-V3-A9ZY-01                     0          0.0            0     0.41
# TCGA-V4-A9E5-01                     0          0.0            0     0.12
# TCGA-V4-A9E7-01                     0          0.0            0     0.29
#
#                  Pearson Correlation      RMSE
# Input Sample
# TCGA-RZ-AB0B-01            -0.005400  1.099710
# TCGA-V3-A9ZX-01             0.019062  1.094536
# TCGA-V3-A9ZY-01             0.038757  1.077862
# TCGA-V4-A9E5-01             0.084018  1.067924
# TCGA-V4-A9E7-01             0.050437  1.066579
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Split data into differnt classes

# %%
def return_subgroups(gene, p, r):
    subgroups = {}
    patients = p.columns[2:]
    val = p.loc[[gene]].values[0,2:]
    for i in range(len(val)):
        if val[i] in subgroups:
            subgroups[val[i]].append((i,patients[i],val[i]))
        else:
            subgroups[val[i]] = [(i,patients[i],val[i])]
    return subgroups

# %%
subgroups = return_subgroups("BAP1", presence_df,results_df)

# %%
print(subgroups.keys())
# Out:
# dict_keys([-1, 0])

# %%
group_1_df = results_df.loc[[t[1] for t in subgroups[-1]]]
group_2_df = results_df.loc[[t[1] for t in subgroups[0]]]
group_1_df = group_1_df[group_1_df.columns.difference(['RMSE','P-value','Pearson Correlation'])]
group_2_df = group_2_df[group_2_df.columns.difference(['RMSE','P-value','Pearson Correlation'])]

# %% [markdown]
# ## BAP1 -1 Group

# %%
td.cell_frequency_barchart(group_1_df)

# %%
td.cell_frequency_boxplot(group_1_df)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['Macrophages', 'CD4 T cells', 'Mast cells', 'NK cells', 'CD8 T cells', 'Plasma cells', 'B cells', 'Monocytes', 'Eosinophils', 'Neutrophils', 'T cells gamma delta', 'DC']

# %%
td.hierarchical_clustering(group_1_df)

# %%
td.pair_plot(group_1_df,xsize=17,ysize=17)

# %% [markdown]
# ## BAP1 0 Group

# %%
td.cell_frequency_barchart(group_2_df)

# %%
td.cell_frequency_boxplot(group_2_df)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['Macrophages', 'CD4 T cells', 'Mast cells', 'Plasma cells', 'B cells', 'NK cells', 'Monocytes', 'CD8 T cells', 'Eosinophils', 'Neutrophils', 'T cells gamma delta', 'DC']

# %%
td.hierarchical_clustering(group_2_df)

# %%
td.pair_plot(group_2_df,xsize=17,ysize=17)

# %% [markdown]
# ## Notes
# There are definitley differences between the two groups. You can see it the best with the frequency boxplots.

# %% [markdown]
# ## Plot KDE of groups distributions and run non-parametric t-test

# %%
expression_df = pd.read_excel('C:/Users/NathanGrant/Programs/TripodsREU/data/uvm_tcga_pan_can_atlas_2018/data_RNA_Seq_v2_expression_median_excel.xlsx',index_col="Hugo_Symbol")

# %%
expression_df.head()
# Out:
#              TCGA-RZ-AB0B-01  TCGA-V3-A9ZX-01  TCGA-V3-A9ZY-01  \
# Hugo_Symbol
# UBE2Q2P2              4.8264           2.1699           0.7299
# RPL41P2              91.0674          91.2986          29.1022
# RPS6KA2             964.7600         869.0410         640.1460
# BRCA1                 0.0000           0.0000           0.0000
# AI894139            174.6680         102.4660          93.4307
#
#              TCGA-V4-A9E5-01  TCGA-V4-A9E7-01  TCGA-V4-A9E8-01  \
# Hugo_Symbol
# UBE2Q2P2              2.6070           4.7598           1.9773
# RPL41P2              20.6022          55.0171          34.4834
# RPS6KA2             780.5070        1287.5200        1088.4800
# BRCA1                 0.0000           0.0000           0.0000
# AI894139             33.2805          93.4107          68.2155
#
#              TCGA-V4-A9E9-01  TCGA-V4-A9EA-01  TCGA-V4-A9EC-01  \
# Hugo_Symbol
# UBE2Q2P2              4.3636           4.5249           0.0000
# RPL41P2              32.2545           8.8462          45.6507
# RPS6KA2             879.2730         558.8230        1054.7400
# BRCA1                 0.0000           0.0000           0.0000
# AI894139             21.0909          54.2986          59.0506
#
#              TCGA-V4-A9ED-01  ...  TCGA-WC-A885-01  TCGA-WC-A888-01  \
# Hugo_Symbol                   ...
# UBE2Q2P2              2.8444  ...           4.2702           5.3313
# RPL41P2              46.1481  ...          39.3498          76.8241
# RPS6KA2             930.1290  ...         763.2960        1105.1000
# BRCA1                 0.0000  ...           0.0000           0.0000
# AI894139             53.4753  ...          35.2290         117.2890
#
#              TCGA-WC-A88A-01  TCGA-WC-AA9A-01  TCGA-WC-AA9E-01  \
# Hugo_Symbol
# UBE2Q2P2              2.4876           9.8639           4.6212
# RPL41P2              70.2985          90.9479          86.2960
# RPS6KA2             970.1490        1436.4100         951.7060
# BRCA1                 0.0000           0.0000           0.0000
# AI894139             56.5920         165.6500         192.7340
#
#              TCGA-YZ-A980-01  TCGA-YZ-A982-01  TCGA-YZ-A983-01  \
# Hugo_Symbol
# UBE2Q2P2              7.7805           0.0000          10.9175
# RPL41P2              58.9273          39.6018          59.2057
# RPS6KA2             801.0690         687.6110         717.3650
# BRCA1                 0.0000           0.0000           0.0000
# AI894139            174.2700          54.8673         183.4980
#
#              TCGA-YZ-A984-01  TCGA-YZ-A985-01
# Hugo_Symbol
# UBE2Q2P2              0.9279           3.4030
# RPL41P2              31.3802          30.2980
# RPS6KA2             806.3090         637.4940
# BRCA1                 0.0000           0.0000
# AI894139             33.4029          46.5075
#
# [5 rows x 80 columns]

# %%
def plot_and_test(expression_df, gene_name,subgroups):
    x = []
    colors= ["b","r","g","y"]
    temp = expression_df.loc[[gene_name]].values[0]
    p = list(expression_df.columns)
    grps = list(subgroups.keys())
    for group in grps:
        x.append([temp[p.index(s[1])] for s in subgroups[group]])
    [sns.kdeplot(x[i],shade=True,color=colors[i],label=grps[i]) for i in range(len(x))]
    for c in combinations(range(len(x)),2):
        print("non-param t-test between ",grps[c[0]],"and ",grps[c[1]],": ", mannwhitneyu(x[c[0]],x[c[1]]))

# %%
plot_and_test(expression_df,"BAP1", subgroups)
# Out:
# non-param t-test between  -1 and  0 :  MannwhitneyuResult(statistic=43.0, pvalue=2.2645416488998719e-13)

# %% [markdown]
# ## Interesting Genes Vizualization

# %%
f_subgroups = return_subgroups("FAM127C", presence_df,results_df)
plot_and_test(expression_df,"FAM127C", f_subgroups)
# Out:
# non-param t-test between  0 and  1 :  MannwhitneyuResult(statistic=180.0, pvalue=0.07779442317822885)
# non-param t-test between  0 and  -1 :  MannwhitneyuResult(statistic=392.0, pvalue=0.4625796354223247)
# non-param t-test between  1 and  -1 :  MannwhitneyuResult(statistic=46.0, pvalue=0.14930883722440513)

# %%
f_df1 = results_df.loc[[t[1] for t in f_subgroups[-1]]]
f_df2 = results_df.loc[[t[1] for t in f_subgroups[0]]]
f_df3 = results_df.loc[[t[1] for t in f_subgroups[1]]]
f_df1 = f_df1[f_df1.columns.difference(['RMSE','P-value','Pearson Correlation'])]
f_df2 = f_df2[f_df2.columns.difference(['RMSE','P-value','Pearson Correlation'])]
f_df3 = f_df3[f_df3.columns.difference(['RMSE','P-value','Pearson Correlation'])]

# %%
td.cell_frequency_boxplot(f_df1)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['Macrophages', 'CD4 T cells', 'Plasma cells', 'NK cells', 'Mast cells', 'Monocytes', 'B cells', 'CD8 T cells', 'Eosinophils', 'Neutrophils', 'T cells gamma delta', 'DC']

# %%
td.cell_frequency_boxplot(f_df2)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['Macrophages', 'CD4 T cells', 'Mast cells', 'NK cells', 'Plasma cells', 'Monocytes', 'CD8 T cells', 'B cells', 'Eosinophils', 'Neutrophils', 'T cells gamma delta', 'DC']

# %%
td.cell_frequency_boxplot(f_df3)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['Macrophages', 'CD4 T cells', 'Mast cells', 'NK cells', 'CD8 T cells', 'Monocytes', 'Plasma cells', 'B cells', 'Eosinophils', 'Neutrophils', 'T cells gamma delta', 'DC']

# %%
p_subgroups = return_subgroups("PTPN23", presence_df,results_df)
plot_and_test(expression_df,"PTPN23", f_subgroups)
# Out:
# non-param t-test between  0 and  1 :  MannwhitneyuResult(statistic=128.0, pvalue=0.008385548142176211)
# non-param t-test between  0 and  -1 :  MannwhitneyuResult(statistic=338.0, pvalue=0.19096768089503852)
# non-param t-test between  1 and  -1 :  MannwhitneyuResult(statistic=21.0, pvalue=0.0044711229515737895)

# %%
p_df1 = results_df.loc[[t[1] for t in p_subgroups[-1]]]
p_df2 = results_df.loc[[t[1] for t in p_subgroups[0]]]
p_df3 = results_df.loc[[t[1] for t in p_subgroups[1]]]
p_df1 = p_df1[p_df1.columns.difference(['RMSE','P-value','Pearson Correlation'])]
p_df2 = p_df2[p_df2.columns.difference(['RMSE','P-value','Pearson Correlation'])]
p_df3 = p_df3[p_df3.columns.difference(['RMSE','P-value','Pearson Correlation'])]

# %%
td.cell_frequency_boxplot(p_df1)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['Macrophages', 'CD4 T cells', 'Mast cells', 'NK cells', 'CD8 T cells', 'Plasma cells', 'B cells', 'Monocytes', 'Eosinophils', 'Neutrophils', 'T cells gamma delta', 'DC']

# %%
td.cell_frequency_boxplot(p_df2)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['Macrophages', 'CD4 T cells', 'Mast cells', 'Plasma cells', 'B cells', 'NK cells', 'Monocytes', 'CD8 T cells', 'Eosinophils', 'Neutrophils', 'T cells gamma delta', 'DC']

# %%
td.cell_frequency_boxplot(p_df3)
# Out:
# Index(['Eosinophils', 'Monocytes', 'Neutrophils', 'Plasma cells',
#        'CD8 T cells', 'T cells gamma delta', 'B cells', 'CD4 T cells',
#        'NK cells', 'Macrophages', 'Mast cells', 'DC'],
#       dtype='object')
# ['CD4 T cells', 'Mast cells', 'Macrophages', 'NK cells', 'Monocytes', 'B cells', 'Eosinophils', 'Neutrophils', 'Plasma cells', 'CD8 T cells', 'T cells gamma delta', 'DC']
