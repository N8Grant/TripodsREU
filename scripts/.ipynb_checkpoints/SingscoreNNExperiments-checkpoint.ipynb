# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import TumorDecon as td
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.mixture import BayesianGaussianMixture
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
mixture_df = pd.read_csv("C:/Users/NathanGrant/Programs/TripodsREU/scripts/TumorDecon/data/Simulation_data/Simulation_SNR100to25.csv",index_col="Hugo_Symbol")
mixture_df.head()
# Out:
#                        0            1            2            3            4  \
# Hugo_Symbol
# A1CF            0.000000   892.965620     0.000000     0.000000   140.254551
# A2M          1709.682881  1291.292027  1959.586116  2092.703274  1384.762990
# A4GALT          0.000000     0.000000   631.484443     0.000000   142.669122
# A4GNT         611.973353   377.161834     0.000000   207.563540   737.459358
# AAAS            0.000000   495.916924   207.867586   478.529626   383.956677
#
#                       5           6            7            8            9  \
# Hugo_Symbol
# A1CF          31.388433  388.188200   513.205451     0.000000    60.984927
# A2M          474.510868  916.179936  1342.087505  1621.588074  1623.044783
# A4GALT       217.856280    0.000000     0.000000     0.000000   291.965697
# A4GNT        500.367377  450.095129     0.000000   171.946069     0.000000
# AAAS         103.082947    0.000000     0.000000     0.000000   447.727558
#
# ...

# %%
groundtruth_df = pd.read_csv("C:/Users/NathanGrant/Programs/TripodsREU/scripts/TumorDecon/data/Simulation_data/Simulation_mixture.csv",index_col="Patient")
groundtruth_df.head()
# Out:
#                 0         1         2         3         4         5         6  \
# Patient
# 0        0.041987  0.029400  0.058375  0.065183  0.011434  0.054252  0.051492
# 1        0.029913  0.048027  0.008742  0.062388  0.021600  0.041344  0.019164
# 2        0.060445  0.002421  0.016912  0.079836  0.073710  0.002900  0.041895
# 3        0.062324  0.057795  0.021215  0.018881  0.108848  0.030902  0.038093
# 4        0.023462  0.067551  0.033406  0.079458  0.038118  0.005731  0.055723
#
#                 7         8         9  ...        12        13        14  \
# Patient                                ...
# 0        0.050393  0.019502  0.050503  ...  0.055866  0.048454  0.014117
# 1        0.062305  0.065441  0.043912  ...  0.078530  0.023266  0.084164
# 2        0.037881  0.080806  0.042998  ...  0.015474  0.066772  0.047766
# 3        0.073227  0.104172  0.040704  ...  0.016990  0.021771  0.021409
# 4        0.046567  0.057377  0.077398  ...  0.011191  0.054797  0.052404
#
# ...

# %%
lm22 = td.read_lm22_file()

# %%
def encode_inputs(rna_df,sig_df):
    df_temp = td.df_normalization(rna_df,"minmax")
    rna_df_red ,sig_df_red = td.keep_common_genes(df_temp,sig_df)
    df_temp = rna_df_red.T
    return df_temp

# %%
input_df = encode_inputs(mixture_df,lm22)

# %%
ss_results = td.SingScore_main(input_df.T)
# Out:
# Running SingScore...
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
#ss_results[ss_results<0] = 0
ss_results = ss_results.fillna(0)
del ss_results['Angiogenesis']
del ss_results['Antigen presenting machinery']
ss_results.head()
# Out:
#                  aDC   B cells  CD8 T cells  Cytotoxic cells        DC  \
# Patient_ID
# 0           0.108775  0.020516     0.089188         0.391973  0.272395
# 1           0.114260  0.010969     0.126534         0.358900  0.064442
# 2           0.181901 -0.086431    -0.016584         0.348596  0.228519
# 3           0.039915  0.045399    -0.088927         0.251205  0.102377
# 4           0.040524 -0.003656     0.114260         0.403606  0.002742
#
#             Eosinophils       iDC  Macrophages  Mast cells  Neutrophils  ...  \
# Patient_ID                                                               ...
# 0              0.103062  0.111822    -0.085793    0.163010    -0.039001  ...
# 1             -0.000229  0.040524    -0.355837    0.177839    -0.001371  ...
# 2             -0.013254  0.072821    -0.176156   -0.012492     0.038848  ...
# 3              0.028336  0.196120    -0.086837    0.277575    -0.088513  ...
# ...

# %%
ss_results.columns
# Out:
# Index(['aDC', 'B cells', 'CD8 T cells', 'Cytotoxic cells', 'DC', 'Eosinophils',
#        'iDC', 'Macrophages', 'Mast cells', 'Neutrophils',
#        'NK CD56bright cells', 'NK CD56dim cells', 'NK cells', 'pDC', 'T cells',
#        'T helper cells', 'Tcm cells', 'Tem cells', 'Tfh cells', 'Tgd cells',
#        'Th1 cells', 'Th17 cells', 'Th2 cells', 'Treg cells'],
#       dtype='object')

# %%
cibersort_results.columns
# Out:
# Index(['B cells naive', 'B cells memory', 'Plasma cells', 'T cells CD8',
#        'T cells CD4 naive', 'T cells CD4 memory resting',
#        'T cells CD4 memory activated', 'T cells follicular helper',
#        'T cells regulatory (Tregs)', 'T cells gamma delta', 'NK cells resting',
#        'NK cells activated', 'Monocytes', 'Macrophages M0', 'Macrophages M1',
#        'Macrophages M2', 'Dendritic cells resting',
#        'Dendritic cells activated', 'Mast cells resting',
#        'Mast cells activated', 'Eosinophils', 'Neutrophils'],
#       dtype='object', name='Patient_ID')

# %%
cibersort_results = td.cibersort_main(input_df.T,lm22)
cibersort_results.head()
# Out:
# Running CiberSort...
# Patient_ID  B cells naive  B cells memory  Plasma cells  T cells CD8  \
# 0                0.033863        0.058634      0.083324     0.017029
# 1                0.055853        0.030540      0.009772     0.045328
# 2                0.051848        0.020857      0.004410     0.064416
# 3                0.067709        0.079240      0.027805     0.002170
# 4                0.046168        0.040111      0.052865     0.061913
#
# Patient_ID  T cells CD4 naive  T cells CD4 memory resting  \
# 0                    0.009140                    0.061523
# 1                    0.012353                    0.038258
# 2                    0.069877                    0.000000
# 3                    0.068529                    0.037391
# 4                    0.032926                    0.000000
#
# Patient_ID  T cells CD4 memory activated  T cells follicular helper  \
# 0                               0.039825                   0.019277
# ...

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(46)),
        tf.keras.layers.Dense(128,activation="relu"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(22)
    ]
)
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt,
              loss='mae',
              metrics=['mae','mape'])

# %%
def format_data(cibersort, singscore, groundtruth, test_size=.2,generated_points=0):
    combined_df = pd.concat([cibersort_results,ss_results],axis=1)
    comb = combined_df.values
    ground = groundtruth.values
    indices = np.random.permutation(comb.shape[0])
    training_idx, test_idx = indices[:int(comb.shape[0]*(1-test_size))], indices[int(comb.shape[0]*(test_size)):]
    X_train, X_test,y_train,y_test = comb[training_idx,:], comb[test_idx,:],ground[training_idx,:],ground[test_idx,:]
    if generated_points != 0:
        merged = np.concatenate((X_train,y_train),axis=1)
        bgm = BayesianGaussianMixture(n_components=int(comb.shape[0]*(1-test_size))).fit(merged)
        sampled = bgm.sample(generated_points)
        sampled = sampled[0]
        gen_x = sampled[:,:46]
        gen_y = sampled[:,46:]
        X_train = np.concatenate((X_train,gen_x),axis=0)
        y_train = np.concatenate((y_train,gen_y),axis=0)
    
    return X_train, X_test,y_train,y_test,test_idx

# %%
X_train, X_test, y_train, y_test,test_index = format_data(cibersort_results,ss_results,groundtruth_df,generated_points=100000)

# %%
history = model.fit(X_train, y_train, epochs=20, 
                    validation_data=(X_test, y_test))
# Out:
# Train on 100080 samples, validate on 80 samples
# Epoch 1/20
# 100080/100080 [==============================] - 10s 96us/sample - loss: 0.0091 - mae: 0.0091 - mape: 23.7760 - val_loss: 0.0167 - val_mae: 0.0167 - val_mape: 261.5200
# Epoch 2/20
# 100080/100080 [==============================] - 9s 88us/sample - loss: 0.0086 - mae: 0.0086 - mape: 22.3120 - val_loss: 0.0165 - val_mae: 0.0165 - val_mape: 272.7250
# Epoch 3/20
# 100080/100080 [==============================] - 9s 86us/sample - loss: 0.0086 - mae: 0.0086 - mape: 22.1200 - val_loss: 0.0167 - val_mae: 0.0167 - val_mape: 290.1454
# Epoch 4/20
# 100080/100080 [==============================] - 9s 85us/sample - loss: 0.0085 - mae: 0.0085 - mape: 22.2418 - val_loss: 0.0165 - val_mae: 0.0165 - val_mape: 240.1545
# Epoch 5/20
# 100080/100080 [==============================] - 9s 86us/sample - loss: 0.0085 - mae: 0.0085 - mape: 22.1531 - val_loss: 0.0164 - val_mae: 0.0164 - val_mape: 275.0093
# Epoch 6/20
# ...

# %%
nn_predictions = model.predict(X_test)
c_results = td.cibersort_main(mixture_df.iloc[:,list(test_index)],lm22)
nn_results = pd.DataFrame(data=nn_predictions,columns=c_results.columns)
nn_results = td.sum_upto_1(nn_results)
nn_predictions = nn_results.values
# Out:
# Running CiberSort...

# %%
print("NN MAE:",mean_absolute_error(y_test,nn_predictions))
print("CIBERSORT MAE:",mean_absolute_error(y_test,c_results.values))
# Out:
# NN MAE: 0.016696292402270895
# CIBERSORT MAE: 0.016152944568219

# %%
lin = LinearRegression().fit(y_test.flatten().reshape(-1, 1),nn_predictions.flatten().reshape(-1, 1))
#plt.scatter(y_test.flatten().reshape(-1, 1),lin.predict(y_test.flatten().reshape(-1, 1)))
plt.scatter(y_test,nn_predictions)
lin.score(y_test.flatten().reshape(-1, 1),nn_predictions.flatten().reshape(-1, 1))**.5
# Out:
# 0.5888683562694449

# %%
lin = LinearRegression().fit(y_test.flatten().reshape(-1, 1),c_results.values.flatten().reshape(-1, 1))
#plt.scatter(y_test.flatten().reshape(-1, 1),lin.predict(y_test.flatten().reshape(-1, 1)))
plt.scatter(y_test,c_results.values)
lin.score(y_test.flatten().reshape(-1, 1),c_results.values.flatten().reshape(-1, 1))**.5
# Out:
# 0.7616665590745434

# %%
ss_newr = td.SingScore_main(mixture_df.iloc[:,list(test_index)])
ss_newr = ss_newr.fillna(0)
del ss_newr['Angiogenesis']
del ss_newr['Antigen presenting machinery']
ssr = ss_newr.values
lin = LinearRegression().fit(y_test.flatten().reshape(-1, 1),ssr.flatten().reshape(-1, 1))
#plt.scatter(y_test.flatten().reshape(-1, 1),lin.predict(y_test.flatten().reshape(-1, 1)))
plt.scatter(y_test,ssr)
lin.score(y_test.flatten().reshape(-1, 1),ssr.flatten().reshape(-1, 1))**.5
# Out:
# Running SingScore...
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-59269a632df8> in <module>
#       4 del ss_newr['Antigen presenting machinery']
#       5 ssr = ss_newr.values
# ----> 6 lin = LinearRegression().fit(y_test.flatten().reshape(-1, 1),ssr.flatten().reshape(-1, 1))
#       7 #plt.scatter(y_test.flatten().reshape(-1, 1),lin.predict(y_test.flatten().reshape(-1, 1)))
#       8 plt.scatter(y_test,ssr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
# ...
