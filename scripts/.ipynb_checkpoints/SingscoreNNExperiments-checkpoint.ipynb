# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import TumorDecon as td
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.mixture import BayesianGaussianMixture
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
mixture_df = pd.read_csv("C:/Users/NathanGrant/Programs/TripodsREU/scripts/TumorDecon/data/Simulation_data/Simulation_SNR100to5.csv",index_col="Hugo_Symbol")
mixture_df.head()
# Out:
#                        0            1            2            3            4  \
# Hugo_Symbol
# A1CF          189.364311   276.227372   104.267251    28.697054   296.146820
# A2M          1364.256599  1239.289091  2116.908009  1768.456793  1136.012086
# A4GALT          0.000000   233.820915   116.652581   312.173105     0.000000
# A4GNT         284.196389   277.334832   345.413967   458.714968   214.712847
# AAAS          131.015559    29.684689   131.304606     0.945879   224.295002
#
#                       5            6           7            8            9  \
# Hugo_Symbol
# A1CF         208.322157   343.290502  362.571761    69.765975   108.687679
# A2M          729.338018  1070.376415  841.686383  1606.747140  1354.015708
# A4GALT       190.201734    51.227503    0.000000     0.000000   230.514764
# A4GNT        212.083277   182.001453  166.074495   408.083165   286.878666
# AAAS         140.637259    63.511066  445.517859    37.338367    82.247556
#
#              ...           90           91           92           93  \
# Hugo_Symbol  ...
# A1CF         ...   263.371765     0.000000    81.340653   249.694179
# A2M          ...  1733.195269  1894.002367  1911.714906  1486.086606
# A4GALT       ...     0.000000     0.000000    12.509306   214.052744
# A4GNT        ...   442.743888     0.000000    30.756553     0.000000
# AAAS         ...    99.726423   448.633177   283.418826    47.189144
#
#                       94           95           96           97           98  \
# Hugo_Symbol
# A1CF          329.039262   298.426071   246.263884   183.588010   168.999810
# A2M          1061.448100  1331.084175  2495.915515  1443.909308  2008.877540
# A4GALT         35.980749     0.000000   170.408628     0.000000   143.959652
# A4GNT         495.355076    63.384024   139.374166   413.569199    71.118304
# AAAS           47.417713     0.000000   205.780367     0.000000     0.000000
#
#                      99
# Hugo_Symbol
# A1CF         245.678629
# A2M          128.430483
# A4GALT        44.448153
# A4GNT        103.270241
# AAAS         166.116612
#
# [5 rows x 100 columns]

# %%
groundtruth_df = pd.read_csv("C:/Users/NathanGrant/Programs/TripodsREU/scripts/TumorDecon/data/Simulation_data/Simulation_mixture.csv",index_col="Patient")
groundtruth_df.head()
# Out:
#                 0         1         2         3         4         5         6  \
# Patient
# 0        0.041987  0.029400  0.058375  0.065183  0.011434  0.054252  0.051492
# 1        0.029913  0.048027  0.008742  0.062388  0.021600  0.041344  0.019164
# 2        0.060445  0.002421  0.016912  0.079836  0.073710  0.002900  0.041895
# 3        0.062324  0.057795  0.021215  0.018881  0.108848  0.030902  0.038093
# 4        0.023462  0.067551  0.033406  0.079458  0.038118  0.005731  0.055723
#
#                 7         8         9  ...        12        13        14  \
# Patient                                ...
# 0        0.050393  0.019502  0.050503  ...  0.055866  0.048454  0.014117
# 1        0.062305  0.065441  0.043912  ...  0.078530  0.023266  0.084164
# 2        0.037881  0.080806  0.042998  ...  0.015474  0.066772  0.047766
# 3        0.073227  0.104172  0.040704  ...  0.016990  0.021771  0.021409
# 4        0.046567  0.057377  0.077398  ...  0.011191  0.054797  0.052404
#
#                15        16        17        18        19        20        21
# Patient
# 0        0.028026  0.063896  0.054038  0.057907  0.041855  0.064365  0.034044
# 1        0.035252  0.071408  0.001722  0.065863  0.019781  0.084790  0.037326
# 2        0.087620  0.043304  0.087087  0.009160  0.013183  0.049630  0.066232
# 3        0.055658  0.071423  0.047555  0.048253  0.046857  0.039450  0.000802
# 4        0.009651  0.081185  0.035069  0.074087  0.056898  0.040362  0.001412
#
# [5 rows x 22 columns]

# %%
lm22 = td.read_lm22_file()

# %%
def encode_inputs(rna_df,sig_df):
    df_temp = td.df_normalization(rna_df,"minmax")
    rna_df_red ,sig_df_red = td.keep_common_genes(df_temp,sig_df)
    df_temp = rna_df_red.T
    return df_temp

# %%
input_df = encode_inputs(mixture_df,lm22)

# %%
ss_results = td.SingScore_main(input_df.T)
# Out:
# Running SingScore...
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
#ss_results[ss_results<0] = 0
ss_results = ss_results.fillna(0)
del ss_results['Angiogenesis']
del ss_results['Antigen presenting machinery']
ss_results.head()
# Out:
#                  aDC   B cells  CD8 T cells  Cytotoxic cells        DC  \
# Patient_ID
# 0           0.148385  0.053118     0.093105         0.371198  0.169104
# 1           0.152651  0.026508     0.147428         0.376849  0.037477
# 2           0.119135  0.033516     0.123139         0.363055  0.280165
# 3           0.047837  0.071095     0.093105         0.335632  0.231718
# 4           0.164839  0.074650     0.193393         0.403440  0.139397
#
#             Eosinophils       iDC  Macrophages  Mast cells  Neutrophils  ...  \
# Patient_ID                                                               ...
# 0              0.034963  0.187995    -0.048707    0.249543    -0.035040  ...
# 1              0.060101  0.183120    -0.119483    0.252590     0.065661  ...
# 2              0.015082  0.138432    -0.104858    0.000508     0.079525  ...
# 3             -0.018510  0.152041    -0.146122    0.250355    -0.086685  ...
# 4             -0.111060  0.165245    -0.084748    0.286309    -0.105271  ...
#
#              T cells  T helper cells  Tcm cells  Tem cells  Tfh cells  \
# Patient_ID
# 0           0.304779        0.127971  -0.075868  -0.236746  -0.041337
# 1           0.288587        0.061243  -0.161792   0.040219  -0.036055
# 2           0.325020        0.195612  -0.037477  -0.400366  -0.076884
# 3           0.339384        0.117916   0.169104  -0.283364  -0.033008
# 4           0.322408        0.150823   0.159963  -0.321755  -0.074853
#
#             Tgd cells  Th1 cells  Th17 cells  Th2 cells  Treg cells
# Patient_ID
# 0            0.090494   0.034735   -0.306216  -0.122029   -0.074040
# 1            0.139854   0.027605   -0.273309  -0.057587   -0.276965
# 2            0.031993   0.049543   -0.000914  -0.028793   -0.498172
# 3            0.037477   0.026691   -0.498172   0.077697   -0.114260
# 4            0.156307   0.021938   -0.200183  -0.031536   -0.123400
#
# [5 rows x 24 columns]

# %%
cibersort_results = td.cibersort_main(input_df.T,lm22)
cibersort_results.head()
# Out:
# Running CiberSort...
# Patient_ID  B cells naive  B cells memory  Plasma cells  T cells CD8  \
# 0                0.050081        0.021317      0.094302     0.041113
# 1                0.034445        0.057088      0.011525     0.038101
# 2                0.051301        0.025301      0.026763     0.044284
# 3                0.059756        0.080095      0.038034     0.009834
# 4                0.017899        0.083983      0.050394     0.042349
#
# Patient_ID  T cells CD4 naive  T cells CD4 memory resting  \
# 0                    0.003775                    0.039375
# 1                    0.016808                    0.031977
# 2                    0.058929                    0.000000
# 3                    0.088894                    0.025002
# 4                    0.040918                    0.000000
#
# Patient_ID  T cells CD4 memory activated  T cells follicular helper  \
# 0                               0.045682                   0.035502
# 1                               0.020618                   0.040183
# 2                               0.038153                   0.029882
# 3                               0.022348                   0.055292
# 4                               0.044270                   0.026542
#
# Patient_ID  T cells regulatory (Tregs)  T cells gamma delta  ...  Monocytes  \
# 0                             0.019579             0.037241  ...   0.054492
# 1                             0.048478             0.033074  ...   0.088586
# 2                             0.062111             0.036329  ...   0.009680
# 3                             0.083431             0.031094  ...   0.028682
# 4                             0.048856             0.055543  ...   0.018456
#
# Patient_ID  Macrophages M0  Macrophages M1  Macrophages M2  \
# 0                 0.076140        0.016470        0.016025
# 1                 0.033556        0.126710        0.020732
# 2                 0.103794        0.066281        0.062620
# 3                 0.030826        0.034313        0.030839
# 4                 0.076915        0.072726        0.008523
#
# Patient_ID  Dendritic cells resting  Dendritic cells activated  \
# 0                          0.041520                   0.063099
# 1                          0.042524                   0.000000
# 2                          0.022588                   0.107455
# 3                          0.047667                   0.054743
# 4                          0.048538                   0.044032
#
# Patient_ID  Mast cells resting  Mast cells activated  Eosinophils  Neutrophils
# 0                     0.044387              0.069455     0.068059     0.038354
# 1                     0.068462              0.029444     0.090934     0.034928
# 2                     0.010745              0.008479     0.053645     0.071541
# 3                     0.051658              0.070687     0.046621     0.002510
# 4                     0.088418              0.061198     0.044849     0.000000
#
# [5 rows x 22 columns]

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(46)),
        tf.keras.layers.Dense(128,activation="relu"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(22)
    ]
)
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt,
              loss='mae',
              metrics=['mae','mape'])

# %%
def format_data(cibersort, singscore, groundtruth, test_size=.2,generated_points=0):
    combined_df = pd.concat([cibersort_results,ss_results],axis=1)
    comb = combined_df.values
    ground = groundtruth.values
    indices = np.random.permutation(comb.shape[0])
    training_idx, test_idx = indices[:int(comb.shape[0]*(1-test_size))], indices[int(comb.shape[0]*(test_size)):]
    X_train, X_test,y_train,y_test = comb[training_idx,:], comb[test_idx,:],ground[training_idx,:],ground[test_idx,:]
    if generated_points != 0:
        merged = np.concatenate((X_train,y_train),axis=1)
        bgm = BayesianGaussianMixture(n_components=int(comb.shape[0]*(1-test_size))).fit(merged)
        sampled = bgm.sample(generated_points)
        sampled = sampled[0]
        gen_x = sampled[:,:46]
        gen_y = sampled[:,46:]
        X_train = np.concatenate((X_train,gen_x),axis=0)
        y_train = np.concatenate((y_train,gen_y),axis=0)
    
    return X_train, X_test,y_train,y_test,test_idx

# %%
X_train, X_test, y_train, y_test,test_index = format_data(cibersort_results,ss_results,groundtruth_df,generated_points=10000)

# %%
history = model.fit(X_train, y_train, epochs=20, 
                    validation_data=(X_test, y_test))
# Out:
# Train on 10080 samples, validate on 80 samples
# Epoch 1/20
# 10080/10080 [==============================] - 2s 153us/sample - loss: 0.0124 - mae: 0.0124 - mape: 36.5832 - val_loss: 0.0203 - val_mae: 0.0203 - val_mape: 267.8524
# Epoch 2/20
# 10080/10080 [==============================] - 1s 70us/sample - loss: 0.0107 - mae: 0.0107 - mape: 29.2858 - val_loss: 0.0199 - val_mae: 0.0199 - val_mape: 296.0606
# Epoch 3/20
# 10080/10080 [==============================] - 1s 69us/sample - loss: 0.0104 - mae: 0.0104 - mape: 28.9702 - val_loss: 0.0193 - val_mae: 0.0193 - val_mape: 300.6923
# Epoch 4/20
# 10080/10080 [==============================] - 1s 67us/sample - loss: 0.0100 - mae: 0.0100 - mape: 27.7640 - val_loss: 0.0188 - val_mae: 0.0188 - val_mape: 330.8333
# Epoch 5/20
# 10080/10080 [==============================] - 1s 67us/sample - loss: 0.0098 - mae: 0.0098 - mape: 27.4440 - val_loss: 0.0183 - val_mae: 0.0183 - val_mape: 306.1547
# Epoch 6/20
# 10080/10080 [==============================] - 1s 68us/sample - loss: 0.0097 - mae: 0.0097 - mape: 27.9594 - val_loss: 0.0178 - val_mae: 0.0178 - val_mape: 344.8794
# Epoch 7/20
# 10080/10080 [==============================] - 1s 68us/sample - loss: 0.0096 - mae: 0.0096 - mape: 26.0204 - val_loss: 0.0182 - val_mae: 0.0182 - val_mape: 301.4902
# Epoch 8/20
# 10080/10080 [==============================] - 1s 68us/sample - loss: 0.0095 - mae: 0.0095 - mape: 26.2239 - val_loss: 0.0179 - val_mae: 0.0179 - val_mape: 298.7553
# Epoch 9/20
# 10080/10080 [==============================] - 1s 67us/sample - loss: 0.0095 - mae: 0.0095 - mape: 27.7206 - val_loss: 0.0177 - val_mae: 0.0177 - val_mape: 316.9207
# Epoch 10/20
# 10080/10080 [==============================] - 1s 67us/sample - loss: 0.0095 - mae: 0.0095 - mape: 25.9991 - val_loss: 0.0176 - val_mae: 0.0176 - val_mape: 322.4716
# Epoch 11/20
# 10080/10080 [==============================] - 1s 68us/sample - loss: 0.0094 - mae: 0.0094 - mape: 27.4956 - val_loss: 0.0176 - val_mae: 0.0176 - val_mape: 271.8469
# Epoch 12/20
# 10080/10080 [==============================] - 1s 77us/sample - loss: 0.0094 - mae: 0.0094 - mape: 25.9071 - val_loss: 0.0178 - val_mae: 0.0178 - val_mape: 294.1277
# Epoch 13/20
# 10080/10080 [==============================] - 1s 68us/sample - loss: 0.0094 - mae: 0.0094 - mape: 26.2492 - val_loss: 0.0179 - val_mae: 0.0179 - val_mape: 364.8413
# Epoch 14/20
# 10080/10080 [==============================] - 1s 67us/sample - loss: 0.0094 - mae: 0.0094 - mape: 26.2237 - val_loss: 0.0178 - val_mae: 0.0178 - val_mape: 258.1509
# Epoch 15/20
# 10080/10080 [==============================] - 1s 69us/sample - loss: 0.0094 - mae: 0.0094 - mape: 25.9669 - val_loss: 0.0174 - val_mae: 0.0174 - val_mape: 299.1800
# Epoch 16/20
# 10080/10080 [==============================] - 1s 72us/sample - loss: 0.0094 - mae: 0.0094 - mape: 25.8912 - val_loss: 0.0177 - val_mae: 0.0177 - val_mape: 306.0336
# Epoch 17/20
# 10080/10080 [==============================] - 1s 69us/sample - loss: 0.0094 - mae: 0.0094 - mape: 25.6922 - val_loss: 0.0177 - val_mae: 0.0177 - val_mape: 310.3172
# Epoch 18/20
# 10080/10080 [==============================] - 1s 69us/sample - loss: 0.0094 - mae: 0.0094 - mape: 25.7097 - val_loss: 0.0181 - val_mae: 0.0181 - val_mape: 284.2695
# Epoch 19/20
# 10080/10080 [==============================] - 1s 70us/sample - loss: 0.0094 - mae: 0.0094 - mape: 26.1512 - val_loss: 0.0175 - val_mae: 0.0175 - val_mape: 287.3232
# Epoch 20/20
# 10080/10080 [==============================] - 1s 70us/sample - loss: 0.0094 - mae: 0.0094 - mape: 25.8358 - val_loss: 0.0183 - val_mae: 0.0183 - val_mape: 321.6837

# %%
nn_predictions = model.predict(X_test)
c_results = td.cibersort_main(mixture_df.iloc[:,list(test_index)],lm22)
nn_results = pd.DataFrame(data=nn_predictions,columns=c_results.columns)
# Out:
# Running CiberSort...

# %%
print("NN MAE:",mean_absolute_error(y_test,nn_predictions))
print("CIBERSORT MAE:",mean_absolute_error(y_test,c_results.values))
# Out:
# NN MAE: 0.01826988141480537
# CIBERSORT MAE: 0.01256841425210489

# %%
lin = LinearRegression().fit(y_test.flatten().reshape(-1, 1),nn_predictions.flatten().reshape(-1, 1))
#plt.scatter(y_test.flatten().reshape(-1, 1),lin.predict(y_test.flatten().reshape(-1, 1)))
plt.scatter(y_test,nn_predictions)
plt.show()
lin.score(y_test.flatten().reshape(-1, 1),nn_predictions.flatten().reshape(-1, 1))**.5
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.
# 0.5007802722223532

# %%
lin = LinearRegression().fit(y_test.flatten().reshape(-1, 1),c_results.values.flatten().reshape(-1, 1))
#plt.scatter(y_test.flatten().reshape(-1, 1),lin.predict(y_test.flatten().reshape(-1, 1)))
plt.scatter(y_test,c_results.values)
lin.score(y_test.flatten().reshape(-1, 1),c_results.values.flatten().reshape(-1, 1))**.5
# Out:
# 0.8346418301059324
